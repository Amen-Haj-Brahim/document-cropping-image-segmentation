# %%
import tensorflow as tf
import cv2 as cv
from pixellib.instance import instance_segmentation 
import matplotlib.pyplot as plt
# Out:
# c:\Users\pc\anaconda3\envs\tfgpu310\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py:37: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top

# %%
image=cv.imread("1.jpg")

# %%
imgs=[]
for i in range(1,5):
  imgs.append(cv.imread(str(i)+".jpg",cv.IMREAD_COLOR))

# %%
plt.figure(figsize=(10,10))
for i in range(1,5):
  plt.subplot(2,4,i)
  plt.imshow(imgs[i-1])
  plt.axis("off")
  plt.title(str(i))

# %%
model = tf.keras.models.load_weights("mask_rcnn_paper_cfg_coco_0002.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = tf.keras.models.load_model("fine_tune/mask_rcnn_coco.h5")
#
# File c:\Users\pc\anaconda3\envs\tfgpu310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\pc\anaconda3\envs\tfgpu310\lib\site-packages\keras\saving\hdf5_format.py:194, in load_model_from_hdf5(filepath, custom_objects, compile)
#     192 model_config = f.attrs.get("model_config")
#     193 if model_config is None:
# --> 194     raise ValueError(
# ...

# %%
image_resized = image.resize((1024, 1024))  # Replace with your training image size
image_array = np.array(image_resized) / 255.0  # Normalize pixel values to [0, 1]
image_tensor = tf.convert_to_tensor(image_array, dtype=tf.float32)
image_tensor = tf.expand_dims(image_tensor, axis=0)  # Add batch dimension

# %%
outputs = model(image_tensor)

# %%
res=model.segmentFrame(imgs[0],show_bboxes=True)

# %%
img1=res[1]

# %%
plt.imshow(img1)
